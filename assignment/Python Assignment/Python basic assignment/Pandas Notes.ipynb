# %%
# Installing pandas to use it
import pandas as pd
print(pd)
# Out:
# <module 'pandas' from 'c:\\users\\zebu\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\pandas\\__init__.py'>

# %%
#data = pd.read_html('https://www.forbes.com/real-time-billionaires/#3f3aefab3d78')

# %%
#print(data)

# %%
#print(f'Extracted {len(data)} table/s')

# %%
data[0]

# %%
import requests
city_list = requests.get('https://en.wikipedia.org/wiki/List_of_cities_in_the_United_Kingdom')
print(city_list.status_code, city_list.reason, len(city_list.text))
print(city_list.text[0::])
# Out:
# 200 OK 375638
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of cities in the United Kingdom - Wikipedia</title>
# ...

# %%
from bs4 import BeautifulSoup as bs
city_list = requests.get('https://en.wikipedia.org/wiki/List_of_cities_in_the_United_Kingdom')
city_list = bs(city_list.text, "lxml")
table = city_list.find_all('table', {'class':'wikitable sortable'})
print(f'Found {len(table)} table/tables.')
table = table[0]
# Out:
# Found 1 table/tables.

# %%
table_rows = table.find_all('tr')
print(f'Found {len(table_rows)} row/rows.')
# Out:
# Found 70 row/rows.

# %%
links = []
for row in table_rows:
    cells = row.find_all('td')

    if cells:
        link = cells[0].find_all('a')[0]
        link = link.attrs['href']
        links.append(f'https://en.wikipedia.org{link}')
    else:
    # We found "th" header cells, instead of "td"
        pass
        print(f'Extracted {len(links)} links. Is this the right number? {"Yes" if len(links) == 69 else "No"}.')
links[0:4]
# Out:
# Extracted 0 links. Is this the right number? No.
# ['https://en.wikipedia.org/wiki/Aberdeen',
#  'https://en.wikipedia.org/wiki/Armagh',
#  'https://en.wikipedia.org/wiki/Bangor,_Gwynedd',
#  'https://en.wikipedia.org/wiki/Bath,_Somerset']

# %%
import pandas as pd

# %%
data=pd.read_csv("open_account_record.csv")

# %%
df=pd.DataFrame(data)

# %%
df1 = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
            "moon,Mr Earth",
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
            "moon,Mr Earth",
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
            "moon,Mr Earth"
        ],
        "Age": [22, 35, 58,16,22, 35, 58,16,22, 35, 58,16],
        "Sex": ["male", "male", "female","Fe","male", "male", "female","Fe","male", "male", "female","Fe"],
    }
)

# %%
df1.dtypes
# Out:
# Name    object
# Age      int64
# Sex     object
# dtype: object

# %%
df1.to_html("daa.html")

# %%
df
# Out:
#                      Name  mobile_number                         email  \
# 0                  ashish   8.248121e+09    ashishyadav@zebuetrade.com
# 1                satheesh   9.876543e+09        sathish@zebuetrade.com
# 2                satheesh   9.876543e+09        sathish@zebuetrade.com
# 3                     NaN            NaN                           NaN
# 4                  ramesh   9.500083e+09         ramesh@zebuetrade.com
# ..                    ...            ...                           ...
# 883  Mohammed Yunus Mulla   8.308788e+09  mohammedyunusmulla@gmail.com
# 884            Achuthan K   9.629351e+09     achuthan.k1987@gmaill.com
# 885   Vinod kumar dhakad    9.512837e+09      vinofdhakadv17@gmail.com
# 886           Vinod Kumar   9.512837e+09      vinofdhakadv17@gmail.com
# 887          Asit Vellodi   9.326242e+09           askvell19@gmail.com
#
#        location                initDateTime  ref               defaultMail  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 888 entries, 0 to 887
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           883 non-null    object
#  1   mobile_number  883 non-null    float64
#  2   email          883 non-null    object
#  3   location       883 non-null    object
#  4   initDateTime   888 non-null    object
#  5   ref            185 non-null    object
#  6   defaultMail    888 non-null    object
#  7   managerMail    888 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 55.6+ KB

# %%
df.head(10)
# Out:
#         Name  mobile_number                       email location  \
# 0     ashish   8.248121e+09  ashishyadav@zebuetrade.com  Chennai
# 1   satheesh   9.876543e+09      sathish@zebuetrade.com  Chennai
# 2   satheesh   9.876543e+09      sathish@zebuetrade.com  Chennai
# 3        NaN            NaN                         NaN      NaN
# 4     ramesh   9.500083e+09       ramesh@zebuetrade.com  chennai
# 5  Praveen G   9.962194e+09    prvnpraveen128@gmail.com  Chennai
# 6    Praveen   9.962194e+09    prvnpraveen128@gmail.com  Chennai
# 7     Ashish   9.876543e+09  ashishyadav@zebuetrade.com  Chennai
# 8   vikraman   7.200952e+09      krvikraman98@gmail.com  chennai
# 9    vignesh   9.940323e+09   vigneshlokesh77@gmail.com  Chennai
#
#                  initDateTime  ref               defaultMail   managerMail
# 0  2021-12-31 12:52:54.536991  NaN  vigneshwar2719@gmail.com  Not Assigned
# 1  2021-12-31 14:02:42.705309  NaN  vigneshwar2719@gmail.com  Not Assigned
# ...

# %%
name=df["Name"]
number=df["mobile_number"]

# %%
name.head()
# Out:
# 0      ashish
# 1    satheesh
# 2    satheesh
# 3         NaN
# 4      ramesh
# Name: Name, dtype: object

# %%
type(number)
# Out:
# pandas.core.series.Series

# %%
number.shape
# Out:
# (888,)

# %%
df[["Name","mobile_number","email","location"]].head(5)
# Out:
#        Name  mobile_number                       email location
# 0    ashish   8.248121e+09  ashishyadav@zebuetrade.com  Chennai
# 1  satheesh   9.876543e+09      sathish@zebuetrade.com  Chennai
# 2  satheesh   9.876543e+09      sathish@zebuetrade.com  Chennai
# 3       NaN            NaN                         NaN      NaN
# 4    ramesh   9.500083e+09       ramesh@zebuetrade.com  chennai

# %%
df[df["mobile_number"]==9876543210]
# Out:
#                        Name  mobile_number  \
# 1                  satheesh   9.876543e+09
# 2                  satheesh   9.876543e+09
# 7                    Ashish   9.876543e+09
# 11                      asd   9.876543e+09
# 23                      sad   9.876543e+09
# 38                   ashish   9.876543e+09
# 40                      asd   9.876543e+09
# 45                 asghishb   9.876543e+09
# 46                 asghishb   9.876543e+09
# 48                      asd   9.876543e+09
# 50                      asd   9.876543e+09
# 74                      asd   9.876543e+09
# 75                      asd   9.876543e+09
# 88                      asd   9.876543e+09
# 89                   ashish   9.876543e+09
# 94                      asd   9.876543e+09
# 95             ashish ebook   9.876543e+09
# 96        ashish contact us   9.876543e+09
# 97        ashish contact us   9.876543e+09
# 99                      asd   9.876543e+09
# 100                     asd   9.876543e+09
# ...

# %%
df[df["Name"]=="asd"]
# Out:
#     Name  mobile_number                       email location  \
# 11   asd   9.876543e+09                  asd@dc.com      sda
# 39   asd   9.987654e+09      asthish@zebuetrade.com      asd
# 40   asd   9.876543e+09  ashishyadav@zebuetrade.com      asd
# 44   asd   9.876545e+09      asthish@zebuetrade.com       sd
# 48   asd   9.876543e+09  ashishyadav@zebuetrade.com       CS
# 50   asd   9.876543e+09  ashishyadav@zebuetrade.com      sad
# 74   asd   9.876543e+09                 ashi@sd.com       as
# 75   asd   9.876543e+09                  asd@dc.com      sad
# 88   asd   9.876543e+09                 ashi@sd.com        d
# 94   asd   9.876543e+09      asthish@zebuetrade.com      asd
# 99   asd   9.876543e+09                  asd@dc.com      das
# 100  asd   9.876543e+09                  asd@dc.com      das
# 101  asd   9.876543e+09                  asd@dc.com      das
# 102  asd   9.876543e+09                  asd@dc.com      das
# ...

# %%
df[df["Name"].isin(["ramesh","ashish"])]
# Out:
#       Name  mobile_number                       email location  \
# 0   ashish   8.248121e+09  ashishyadav@zebuetrade.com  Chennai
# 4   ramesh   9.500083e+09       ramesh@zebuetrade.com  chennai
# 38  ashish   9.876543e+09  ashishyadav@zebuetrade.com  chennai
# 89  ashish   9.876543e+09  ashishyadav@zebuetrade.com  chennai
#
#                   initDateTime  ref               defaultMail   managerMail
# 0   2021-12-31 12:52:54.536991  NaN  vigneshwar2719@gmail.com  Not Assigned
# 4   2022-01-01 15:11:41.810822  NaN  vigneshwar2719@gmail.com  Not Assigned
# 38  2022-01-04 06:44:47.957423  NaN  vigneshwar2719@gmail.com  Not Assigned
# 89  2022-01-05 09:58:27.466907  NaN  vigneshwar2719@gmail.com  Not Assigned

# %%
df[(df["Name"]=="ramesh") | (df["Name"]=="ashish")]
# Out:
#       Name  mobile_number                       email location  \
# 0   ashish   8.248121e+09  ashishyadav@zebuetrade.com  Chennai
# 4   ramesh   9.500083e+09       ramesh@zebuetrade.com  chennai
# 38  ashish   9.876543e+09  ashishyadav@zebuetrade.com  chennai
# 89  ashish   9.876543e+09  ashishyadav@zebuetrade.com  chennai
#
#                   initDateTime  ref               defaultMail   managerMail
# 0   2021-12-31 12:52:54.536991  NaN  vigneshwar2719@gmail.com  Not Assigned
# 4   2022-01-01 15:11:41.810822  NaN  vigneshwar2719@gmail.com  Not Assigned
# 38  2022-01-04 06:44:47.957423  NaN  vigneshwar2719@gmail.com  Not Assigned
# 89  2022-01-05 09:58:27.466907  NaN  vigneshwar2719@gmail.com  Not Assigned

# %%
df["Name"].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 883     True
# 884     True
# 885     True
# 886     True
# 887     True
# Name: Name, Length: 888, dtype: bool

# %%
df[(df["Name"].notna()==False)]
# Out:
#    Name  mobile_number email location                initDateTime  \
# 3   NaN            NaN   NaN      NaN  2022-01-01 09:47:35.218310
# 90  NaN            NaN   NaN      NaN  2022-01-05 09:58:51.957325
# 91  NaN            NaN   NaN      NaN  2022-01-05 10:01:11.057745
# 92  NaN            NaN   NaN      NaN  2022-01-05 10:01:11.073197
# 93  NaN            NaN   NaN      NaN  2022-01-05 10:01:11.074097
#
#             ref               defaultMail   managerMail
# 3           NaN  vigneshwar2719@gmail.com  Not Assigned
# 90  /contact_us  vigneshwar2719@gmail.com  Not Assigned
# 91  /contact_us  vigneshwar2719@gmail.com  Not Assigned
# 92  /contact_us  vigneshwar2719@gmail.com  Not Assigned
# 93  /contact_us  vigneshwar2719@gmail.com  Not Assigned

# %%
df.loc[(df["mobile_number"]==9876543210),"Name"]
# Out:
# 1                    satheesh
# 2                    satheesh
# 7                      Ashish
# 11                        asd
# 23                        sad
# 38                     ashish
# 40                        asd
# 45                   asghishb
# 46                   asghishb
# 48                        asd
# 50                        asd
# 74                        asd
# 75                        asd
# 88                        asd
# 89                     ashish
# 94                        asd
# 95               ashish ebook
# 96          ashish contact us
# 97          ashish contact us
# 99                        asd
# 100                       asd
# 101                       asd
# 102                       asd
# 104             asd contact1
# 105                 asd ebook
# 106             asd contact 2
# 113                       asd
# 114                   asd con
# 115            asd contact us
# 116            asd contact us
# 205                      Test
# ...
